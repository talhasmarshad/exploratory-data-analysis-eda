# %%
world = {"China":30.50,"India":2.288,"Albania":39.11}

# %%
print(world)
# Out:
# {'China': 30.5, 'India': 2.288, 'Albania': 39.11}

# %%
world["India"]
# Out:
# 2.288

# %%
world_dic = {
    "COuntries": ["China","India","Albania"],
    "Population":[30.50,2.88,39.21]
}

# %%
### Dataframe (tbale)

# %%
import pandas as pd

# %%
df = pd.DataFrame(world_dic)
print(df)
# Out:
#   COuntries  Population
# 0     China       30.50
# 1     India        2.88
# 2   Albania       39.21

# %%
#method-1
df.COuntries
# Out:
# 0      China
# 1      India
# 2    Albania
# Name: COuntries, dtype: object

# %%
print(type(df), type(df.COuntries))
# Out:
# <class 'pandas.core.frame.DataFrame'> <class 'pandas.core.series.Series'>

# %%
#method-2 (preferred)
df["COuntries"]
# Out:
# 0      China
# 1      India
# 2    Albania
# Name: COuntries, dtype: object

# %%
df.head(2)
# Out:
#   COuntries  Population
# 0     China       30.50
# 1     India        2.88

# %%
df.tail(2)
# Out:
#   COuntries  Population
# 1     India        2.88
# 2   Albania       39.21

# %%
df.sample()
# Out:
#   COuntries  Population
# 1     India        2.88

# %%
df.index
# Out:
# RangeIndex(start=0, stop=3, step=1)

# %%
df.columns
# Out:
# Index(['COuntries', 'Population'], dtype='object')

# %%
df.shape
# Out:
# (3, 2)

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 3 entries, 0 to 2
# Data columns (total 2 columns):
#  #   Column      Non-Null Count  Dtype
# ---  ------      --------------  -----
#  0   COuntries   3 non-null      object
#  1   Population  3 non-null      float64
# dtypes: float64(1), object(1)
# memory usage: 180.0+ bytes

# %%
import pandas as pd

# Example DataFrame
df = pd.DataFrame({
    'Country': ['USA', 'China', 'India'],
    'GDP': [59850, 10660, 1800],
    'LifeExp': [78.5, 76.9, 69.4]
})

# Rename columns
df_renamed = df.rename(columns={'GDP': 'GDP_per_Capita', 'LifeExp': 'Life_Expectancy'})

print(df_renamed)
# Out:
#   Country  GDP_per_Capita  Life_Expectancy
# 0     USA           59850             78.5
# 1   China           10660             76.9
# 2   India            1800             69.4
